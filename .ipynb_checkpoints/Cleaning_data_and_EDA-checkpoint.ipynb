# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Make plots appear in notebook
# %matplotlib inline

# %%
# Load CSV
df = pd.read_csv("data/Film_Dataset.csv")

# Check first 5 rows
df.head()
# Out:
#          Film_Name Release_Date     Category Language  Viewer_Rate  \
# 0  Chennai Express    9/12/2021      Romance    Hindi          4.5
# 1   Mountain Trail    4/27/2020       Comedy  English          3.5
# 2     Eternal Hope     7/4/2020      Romance  English          4.6
# 3  Seoul Heartbeat    4/17/2020       Comedy  English          4.1
# 4      Shadow Pact    2/24/2022  Documentary  English          4.3
#
#    Number_of_Views Viewing_Month
# 0            36395       2022-09
# 1            93162       2021-07
# 2            98663       2021-04
# 3           112635       2020-07
# 4            29496       2023-05

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film_Name        460 non-null    object
#  1   Release_Date     460 non-null    object
#  2   Category         460 non-null    object
#  3   Language         460 non-null    object
#  4   Viewer_Rate      460 non-null    float64
#  5   Number_of_Views  460 non-null    int64
#  6   Viewing_Month    460 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 25.3+ KB
#        Viewer_Rate  Number_of_Views
# count   460.000000       460.000000
# mean      4.220217     94964.213043
# std       0.398915     35857.934071
# min       3.500000     25397.000000
# 25%       3.900000     69759.500000
# 50%       4.200000     94234.000000
# 75%       4.600000    116376.500000
# max       4.900000    229647.000000

# %%
# Convert dates
df['Release_Date'] = pd.to_datetime(df['Release_Date'], errors='coerce')
df['Viewing_Month'] = pd.to_datetime(df['Viewing_Month'], errors='coerce')

# Remove duplicates
df = df.drop_duplicates()

# Remove missing values
df = df.dropna().reset_index(drop=True)

# %%
df['Viewing_Month'].head()
df['Viewing_Month'].dt.year.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df['Viewing_Month'].head()
#       2 df['Viewing_Month'].dt.year.value_counts()
#
# NameError: name 'df' is not defined

# %%
df = df[df['Viewing_Month'].dt.year != 2026].reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = df[df['Viewing_Month'].dt.year != 2026].reset_index(drop=True)
#
# NameError: name 'df' is not defined

# %%
df['Movie_ID'] = (df['Film_Name'] + df['Release_Date'].astype(str) +
                  df['Category'] + df['Language']).apply(lambda x: hash(x))

df[['Film_Name','Release_Date','Category','Language','Movie_ID']].head()
# Out:
#          Film_Name Release_Date     Category Language             Movie_ID
# 0  Chennai Express   2021-09-12      Romance    Hindi  3952496268324879685
# 1   Mountain Trail   2020-04-27       Comedy  English -1506253079912163856
# 2     Eternal Hope   2020-07-04      Romance  English   -82967051559058391
# 3  Seoul Heartbeat   2020-04-17       Comedy  English -5714431524983853846
# 4      Shadow Pact   2022-02-24  Documentary  English -1225629534403330415

# %%
today = pd.Timestamp.today()

# Days since release
df['days_since_release'] = (today - df['Release_Date']).dt.days
df['days_since_release'] = df['days_since_release'].replace(0, 1)

# Months since release
df['months_since_release'] = df['days_since_release'] / 30

# Trending score = views per month
df['trending_score'] = df['Number_of_Views'] / df['months_since_release']

# %%
df.isnull().sum()
df.duplicated().sum()
df.describe()
df['Category'].value_counts()
df['Language'].value_counts()
# Out:
# Language
# Hindi        71
# Tamil        60
# Malayalam    50
# Chinese      50
# Sinhala      50
# English      49
# Taiwanese    40
# Pakistani    40
# French       15
# Spanish      15
# Japanese     10
# Korean       10
# Name: count, dtype: int64

# %%
df.sort_values('Number_of_Views', ascending=False).head(10)
# Out:
#            Film_Name Release_Date       Category Language  Viewer_Rate  \
# 123    Lahore Nights   2024-07-10        Romance    Hindi          4.1
# 341  Seoul Heartbeat   2023-08-25        Romance  Chinese          4.6
# 160     Crimson Tide   2021-01-01        Romance    Hindi          4.3
# 339      Mirror Maze   2021-05-21        Romance  Chinese          4.6
# 336  Chennai Express   2020-12-28  Action/Sci-Fi  Chinese          4.7
# 378    Lahore Nights   2020-11-20  Action/Sci-Fi  Chinese          4.5
# 138      Desert Trek   2024-03-31  Action/Sci-Fi    Hindi          3.7
# 38   Seoul Heartbeat   2020-10-18        Romance  English          4.5
# 285      Mirror Maze   2024-02-19        Romance  Sinhala          4.7
# 19     Lahore Nights   2021-08-16        Romance  English          4.2
#
#      Number_of_Views Viewing_Month             Movie_ID  days_since_release  \
# 123           229647    2025-02-01  8909422516638406413                 519
# 341           226835    2024-02-01 -3085346510769203852                 839
# 160           203753    2021-02-01  8935944322239386254                1805
# 339           194188    2022-12-01  6004224590180561978                1665
# 336           191231    2022-07-01  2493589970931819757                1809
# 378           184630    2022-07-01 -5525180462557173561                1847
# 138           180489    2025-07-01  7061065568253321268                 620
# 38            179123    2022-02-01 -4352954593312004017                1880
# 285           173789    2024-02-01 -8934977912931388033                 661
# 19            171661    2023-02-01  -931818580195956445                1578
#
#      months_since_release  trending_score
# 123             17.300000    13274.393064
# 341             27.966667     8110.905840
# 160             60.166667     3386.476454
# 339             55.500000     3498.882883
# 336             60.300000     3171.326700
# 378             61.566667     2998.863021
# 138             20.666667     8733.338710
# 38              62.666667     2858.345745
# 285             22.033333     7887.549168
# 19              52.600000     3263.517110

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Viewer_Rate'], bins=10, kde=True)
plt.title("Viewer Rating Distribution")
plt.show()

# %%
category_views = df.groupby('Category')['Number_of_Views'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,5))
sns.barplot(x=category_views.index, y=category_views.values)
plt.xticks(rotation=45)
plt.title("Total Views by Category")
plt.ylabel("Number of Views")
plt.show()

# %%
monthly_views = df.groupby('Viewing_Month')['Number_of_Views'].sum()

plt.figure(figsize=(12,5))
monthly_views.plot(kind='line', marker='o')
plt.title("Monthly Viewing Trend")
plt.xlabel("Month")
plt.ylabel("Number of Views")
plt.show()

# %%
top_trending = df.sort_values('trending_score', ascending=True).head(10)

plt.figure(figsize=(10,5))
sns.barplot(x='trending_score', y='Film_Name', data=top_trending)
plt.title("Top Trending Movies")
plt.xlabel("Trending Score")
plt.ylabel("Movie Name")
plt.show()

# %%
fig = px.pie(df, names='Category', values='Number_of_Views', title='Views by Category')
fig.show()

# %%
df.to_csv("data/Film_Dataset_Cleaned.csv", index=False)
print("Cleaned dataset saved!")
# Out:
# Cleaned dataset saved!
